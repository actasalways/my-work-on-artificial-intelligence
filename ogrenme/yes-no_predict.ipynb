# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
import numpy as np

# %%
#ses = "0f7dc557_nohash_1.wav"
ses="sesim.wav"
x,sr = librosa.load(ses)
# x -> ses zaman serisi
# sr -> ses frekansı(Hz)
print(x)
print(sr)
# Out:
# [ 0.0000000e+00 -6.1035156e-05 -1.2207031e-04 ...  3.5202026e-02
#   3.3264160e-02  3.0166626e-02]
# 22050

# %%
ipd.Audio(ses)
ipd.Audio(x,rate=sr)  #Bu şekilde de oynatılabiliyor.
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(10,2))
librosa.display.waveplot(x,sr=sr)

# %%
from keras.models import load_model
model=load_model('model.h5')
print("model yüklendi")
# Out:
# Using TensorFlow backend.
# model yüklendi

# %%
classes=["no","yes"]


ses = "sesim.wav"
samples, sample_rate = librosa.load(ses,sr=6048)

#8k katları 

print(samples.shape)



def predict(audio):
    prob=model.predict(audio.reshape(-1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]


print("Text:",predict(samples))
# Out:
# (8000,)
# Text: yes
