# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
import numpy as np
import pandas as pd
from scipy.fft import fft,fftshift
from math import pi

# %%
#ses = "0f7dc557_nohash_1.wav"
ses="1011yes12.wav"
x,sr = librosa.load(ses,sr=8000)
# x -> ses zaman serisi
# sr -> ses frekansı(Hz)
print(x)
print(x.shape)

print(sr)
# Out:
# [-4.0942491e-06 -2.7073013e-06 -1.5495056e-06 ... -5.7119909e-03
#  -9.6131274e-03  0.0000000e+00]
# (39939,)
# 8000

# %%
plt.figure(figsize=(10,2))
librosa.display.waveplot(x,sr=sr)

# %%
ipd.Audio(ses)
ipd.Audio(x,rate=sr)  #Bu şekilde de oynatılabiliyor.
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Fs=9000
t=np.arange(0,1,1/Fs)
f=20

z=np.sin(2*pi*f*t)

plt.subplot(2,1,1)
plt.plot(x); plt.title('Signal')
plt.xlabel('Time(s)'); plt.ylabel('Amplitute')


n=np.size(t) # frakans ekseni oluşturma
fr=(Fs/2)*np.linspace(0,1,n/2)
#önce verileri pozitif yap - daha sağlıklı sonuç için


X=fft(x)
X_m=abs((2/n)*X[0:np.size(fr)])


plt.subplot(2,1,2)
plt.plot(fr,X_m)
plt.title('Magnitute Spectrum')
plt.xlabel('Frekans(Hz)'); plt.ylabel('Magnitude-büyüklük')
plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   del sys.path[0]
